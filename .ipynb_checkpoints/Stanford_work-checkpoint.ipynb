# %%
import pandas as pd
import numpy as np
import random

# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(1000,4), columns = ['a', 'b', 'c', 'd'])

# %%
pd.tools.plotting.scatter_matrix(df, alpha=0.2, figsize=(6,6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1129f54a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114e309e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114e57630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114ebc588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x114f05d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114f41f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114f8d8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114fcbda0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11514da90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115183be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1151d1eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1151f4b00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11535cd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1153ad278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1153e86d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115432dd8>]], dtype=object)

# %%
import seaborn as sns

# %%
pd.tools.plotting.scatter_matrix(df, alpha=0.2, figsize=(10,10), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1179ea780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117a71278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ab1978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117afbc88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117b3a438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117b81d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ba2d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117d13860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117d62390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117d99ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117de7c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117f27978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117f73c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117df7c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117fc8f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118815ac8>]], dtype=object)

# %%
sns.set(style='darkgrid')

# %%
df_i = sns.load_dataset('iris')
sns.pairplot(df_i)

# %%
sns.pairplot(df_i, hue='species')

# %%
df_i.head()

# %%
df_i.hist()

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
ax = sns.regplot(x='total_bill', y='tip', data=tips)

# %%
import matplotlib.pyplot as pyplt
import seaborn as sns

tips = sns.load_dataset('tips')
pyplt.subplot(1,3,1)
ax1 = sns.regplot(x='total_bill', y='tip', data=tips)

pyplt.subplot(1,3,2)
ax2 = sns.regplot(x='petal_length', y='petal_width', data=df_i)

pyplt.subplot(1,3,3)
ax2 = sns.regplot(x='petal_length', y='sepal_width', data=df_i)

#more concise way would be
#fig, ax = pyplt.subplot(133)

# %%
#http://stackoverflow.com/questions/34162443/why-do-many-examples-use-fig-ax-plt-subplots-in-matplotlib-pyplot-python

fig, ax = pyplt.subplots(1,3)
fig.tight_layout()

ax[1] = sns.regplot(x='petal_length', y='sepal_width', data=df_i)

# %%
"""
#3.2.R1
We run a linear regression and the slope estimate is 0.5 with estimated standard error of 0.2. What is the largest value of b for which we would NOT reject the null hypothesis that β1=b? (assume normal approximation to t distribution, and that we are using the 5% significance level for a two-sided test; need two significant digits of accuracy)
#ans 0.892, b/c highest bound of CI
"""

slope = .5
se_hat = .2

print(1.96*(se_hat))

ci_p = slope + 1.96*se_hat
ci_m = slope - 1.96*se_hat

result = ci_p, ci_m
print(result)

# %%
slope = .08

print(2*(se_hat**2))

ci_p = slope + 2*se_hat**2
ci_m = slope - 2*se_hat**2


result = ci_p, ci_m
print(result)

# %%
np.sqrt(.4)

# %%
np.sqrt(.6)

# %%
df_i.corr()

# %%
ads = pd.read_csv('data/Advertising.csv'
                  , usecols=[1,2,3,4]
                  , header=0
                  , names = ['TV', 'Radio', 'Newspaper', 'Sales'])

# %%
ads.head()

# %%
ads.corr()

# %%
import statsmodels.api as sm

# %%
ads[['TV', 'Radio']].head()

# %%
ads['intercept'] = np.ones((len(ads), ))

# %%
myresult = sm.OLS(ads['Sales'], ads[['intercept', 'TV', 'Radio', 'Newspaper']]).fit()

# %%
myresult.summary()

# %% [markdown]
# notice how little affect of newspaper. and how high the corr between newspaper and radio

# %%
credit = pd.read_csv('data/Credit.csv')
credit.drop(['here'], inplace=True, axis=1)
credit.head()

# %%
credit.hist()

# %%
sns.pairplot(credit)

# %%
credit.corr()

# %%
sns.heatmap(credit.corr(), vmax=.3)

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
pyplt.figure(figsize=(11,9))
sns.heatmap(credit.corr(), cmap=cmap, square=True, cbar_kws={'shrink': .6}, linewidths=1)

# %%
sns.set(style='white')
mask = np.zeros_like(credit.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True


cmap = sns.diverging_palette(220, 10, as_cmap=True)
pyplt.figure(figsize=(11,9))
sns.heatmap(credit.corr(),mask=mask,  cmap=cmap, square=True, linewidths=1)

# %%
mask[np.triu_indices_from(mask)] = True

# %%
mask

# %% [markdown]
# credit.head()

# %%
credit.head()

# %%
X_credit = credit.copy()

# %%
X_credit['dum_female'] = X_credit['Gender'] == 'Female'
X_credit['dum_female'] = X_credit['dum_female'].astype(int)
X_credit['intercept'] = 1

# %%
credit_ols = sm.OLS(X_credit['Balance'], X_credit[['intercept', 'dum_female']]).fit()
credit_ols.summary()

# %%
sns.pairplot(credit, hue='Gender')

# %%
sns.pairplot(credit, hue='Married')

# %%
sns.pairplot(credit, hue='Student')

# %%
sns.pairplot(credit, hue='Ethnicity')

# %%
#for ethnicity, add in more dummy variables for more 

X_credit['Asian'] = X_credit['Ethnicity'] == 'Asian'
X_credit['Caucasian'] = X_credit['Ethnicity'] == 'Caucasian'

X_credit['Asian'] = X_credit['Asian'].astype(int)
X_credit['Caucasian'] = X_credit['Caucasian'].astype(int)

credit_ethn = sm.OLS(X_credit['Balance'], X_credit[['intercept', 'Asian', 'Caucasian']]).fit()
credit_ethn.summary()

# %%
531-18.69
